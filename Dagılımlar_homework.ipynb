# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from scipy.stats import norm
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
dagilim = np.random.normal(250,60,1000)

# %%
plt.hist(dagilim)
plt.show()

# %%
# QQ Çizgesi
standart_dagilim=np.random.normal(0,1,1000)

# %%
dagilim.sort()
standart_dagilim.sort()

# %%
from scipy import stats
import matplotlib.pyplot as sns

plt.figure(figsize=(8,5),dpi=100)
stats.probplot(dagilim,plot=plt) # in here; size len must not necessary same length x,y 
plt.show()

# %%
plt.figure(figsize=(8,5),dpi=100)
plt.title("QQ Çizelgesi Plot ile Çizilmiştir")
plt.xlabel("standart dagilim Kümesi")
plt.ylabel("Dagilim Veri Kümesi")
plt.plot(standart_dagilim,dagilim,"o") # in here; size len must be same length x,y  
plt.show()

# %% [markdown]
# ## Hisse Senedi Dağılımı

# %%
df=pd.read_csv('Google.csv')

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2015-03-27  551.485901  553.759644  546.629211  546.838684  546.838684
# 1  2015-03-30  550.109680  551.954590  546.669128  550.518555  550.518555
# 2  2015-03-31  548.494080  553.191223  545.223083  546.499573  546.499573
# 3  2015-04-01  547.097961  549.630981  538.022888  541.074463  541.074463
# 4  2015-04-02  539.369141  539.369141  532.385315  534.063721  534.063721
#
#     Volume
# 0  1897400
# 1  1287500
# 2  1588000
# 3  1963000
# 4  1716300

# %%
"""x-(x-1)/x-1
x= x zamanındaki hisse senedi fiyatı"""
# Out:
# 'x-(x-1)/x-1\nx= x zamanındaki hisse senedi fiyatı'

# %%
import pandas as pd 
ready=df.groupby('Date')['Close'].transform(lambda x: x - (x -1)/ x-1)

# %%
plt.hist(ready)
plt.show()

# %%
from scipy import stats

plt.figure(figsize=(8,5),dpi=100)
stats.probplot(ready,plot=plt)
plt.show()
